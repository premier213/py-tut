# %%
from PIL import Image

# %%
sea = Image.open("sea.jpg")

# %%
sea.show()

# %%
sea.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
sea.format
# Out:
# 'JPEG'

# %%
sea.filename
# Out:
# 'sea.jpg'

# %%
sea.crop((10,10,500,500))
# Out:
# <PIL.Image.Image image mode=RGB size=490x490>

# %%
sea.resize((250,250))
# Out:
# <PIL.Image.Image image mode=RGB size=250x250>

# %%
sea.putalpha(128)

# %%
sea.save("10.png")
